# %% [markdown]
# ##  Insights and Visualization of WeRateDogs Twitter Archive

# %% [markdown]
# **Most Dogs as per our grapth below we see that the most dogs are rated between 9-13**

# %% [markdown]
# ![dog-dris.png](attachment:dog-dris.png)

# %% [markdown]
# As per our view grapth above we see that most dogs are rated highest at 12 and very close between 11 and 10 hence we can say that almost 600 dogs are rated 12 while roughly 450 are rated 11 while around 440 are rated 10.
# We aslo view that the highest rating is 14 exluding the outerliers(15-1776). With this infomation we can say that WeRateDogs is probably very conservative when it comes to rating dogs

# %% [markdown]
# **Most Used Twitter Source-Twitter accounts for 98% there tweets**

# %% [markdown]
# ![most-viewed.png](attachment:most-viewed.png)

# %% [markdown]
# As per the grapth above we see that WeRateDogs mostly use twitter for iphone to tweet and we can conclude that thats the most preffered mode of tweeting while tweetdeck is the least hence we can conclude its not there prefrence or they rarely consider.Excluding vine-make a scene outlier as vine as a company was shutdown therefore its irrelevant in our current age to be considered a twitter source

# %% [markdown]
# **Most comman names given to dogs-charlie is the most common**

# %% [markdown]
# ![top-named.png](attachment:top-named.png)

# %% [markdown]
# As per our plot above we see that charlie is the common name give to dogs will other names we see there not far off
